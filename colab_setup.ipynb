# %% [markdown]
# # autoresearch for Crypto Trading
#
# Modified to run on Colab (T4 GPU) with BTC/USDT price data.

# %%
# @title Install dependencies
# !pip install uv -q
# !git clone https://github.com/karpathy/autoresearch.git
# %cd autoresearch

# %%
# @title Install project deps
import sys
# !uv sync 2>&1 | tail -5
# Install extra deps for crypto and FA2
# !uv pip install yfinance flash-attn --quiet 2>&1 | tail -3

# %%
# @title Download BTC data & prepare tokenizer
# !python prepare_crypto.py

# %%
# @title Run training (5 min)
# !uv run train_crypto.py
